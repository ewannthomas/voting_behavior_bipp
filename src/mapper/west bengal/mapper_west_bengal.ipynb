# %%
 #install fuzzywuzzy
# !pip install fuzzywuzzy
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import fuzzywuzzy as fw
from fuzzywuzzy import process
import openpyxl as op
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('west_bengal_masterlist.xlsx', sheet_name=0)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status ': 'File Status'}, inplace=True)
df2.rename(columns={'Error comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'WEST BENGAL'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
df1_state['Note'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Note'])


df1_state.to_excel('WEST BENGAL vs 2016.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE   DIST_NAME  AC_NO  \
# 674  674         3       19  WEST BENGAL        3  KOCH BIHAR      1
# 675  675         1       19  WEST BENGAL        3  KOCH BIHAR      2
# 676  676         1       19  WEST BENGAL        3  KOCH BIHAR      3
# 677  677         1       19  WEST BENGAL        3  KOCH BIHAR      4
# 678  678         1       19  WEST BENGAL        3  KOCH BIHAR      5
# ..   ...       ...      ...          ...      ...         ...    ...
# 963  963        41       19  WEST BENGAL        8     BIRBHUM    290
# 964  964        42       19  WEST BENGAL        8     BIRBHUM    291
# 965  965        42       19  WEST BENGAL        8     BIRBHUM    292
# 966  966        42       19  WEST BENGAL        8     BIRBHUM    293
# 967  967        42       19  WEST BENGAL        8     BIRBHUM    294
#
#                    AC_NAME  PC_NO          PC_NAME  PC_ID STATUS  Shape_Leng  \
# 674         MEKLIGANJ (SC)      3  JALPAIGURI (SC)   1903           3.646516
# 675       MATHABHANGA (SC)      1  COOCHBEHAR (SC)   1901           1.329057
# 676  COOCHBEHAR UTTAR (SC)      1  COOCHBEHAR (SC)   1901           1.123028
# 677     COOCHBEHAR DAKSHIN      1  COOCHBEHAR (SC)   1901           0.861036
# 678        SITALKUCHI (SC)      1  COOCHBEHAR (SC)   1901           1.858278
# ..                     ...    ...              ...    ...    ...         ...
# 963             MAYURESWAR     41      BOLPUR (SC)   1941           1.062228
# 964              RAMPURHAT     42          BIRBHUM   1942           1.680656
# 965                 HANSAN     42          BIRBHUM   1942           1.430126
# 966                NALHATI     42          BIRBHUM   1942           1.138946
# 967                MURARAI     42          BIRBHUM   1942           1.086502
#
#      Shape_Area
# 674    0.046919
# 675    0.033107
# 676    0.034835
# 677    0.023555
# 678    0.046011
# ..          ...
# 963    0.034775
# 964    0.038697
# 965    0.026374
# 966    0.027210
# 967    0.026636
#
# [294 rows x 14 columns]

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('west_bengal_masterlist.xlsx', sheet_name=1)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status ': 'File Status'}, inplace=True)
df2.rename(columns={'Error comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'WEST BENGAL'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
# df1_state['Interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Interim'])
df1_state['Note'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Note'])


df1_state.to_excel('WEST BENGAL vs 2021.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE   DIST_NAME  AC_NO  \
# 674  674         3       19  WEST BENGAL        3  KOCH BIHAR      1
# 675  675         1       19  WEST BENGAL        3  KOCH BIHAR      2
# 676  676         1       19  WEST BENGAL        3  KOCH BIHAR      3
# 677  677         1       19  WEST BENGAL        3  KOCH BIHAR      4
# 678  678         1       19  WEST BENGAL        3  KOCH BIHAR      5
# ..   ...       ...      ...          ...      ...         ...    ...
# 963  963        41       19  WEST BENGAL        8     BIRBHUM    290
# 964  964        42       19  WEST BENGAL        8     BIRBHUM    291
# 965  965        42       19  WEST BENGAL        8     BIRBHUM    292
# 966  966        42       19  WEST BENGAL        8     BIRBHUM    293
# 967  967        42       19  WEST BENGAL        8     BIRBHUM    294
#
#                    AC_NAME  PC_NO          PC_NAME  PC_ID STATUS  Shape_Leng  \
# 674         MEKLIGANJ (SC)      3  JALPAIGURI (SC)   1903           3.646516
# 675       MATHABHANGA (SC)      1  COOCHBEHAR (SC)   1901           1.329057
# 676  COOCHBEHAR UTTAR (SC)      1  COOCHBEHAR (SC)   1901           1.123028
# 677     COOCHBEHAR DAKSHIN      1  COOCHBEHAR (SC)   1901           0.861036
# 678        SITALKUCHI (SC)      1  COOCHBEHAR (SC)   1901           1.858278
# ..                     ...    ...              ...    ...    ...         ...
# 963             MAYURESWAR     41      BOLPUR (SC)   1941           1.062228
# 964              RAMPURHAT     42          BIRBHUM   1942           1.680656
# 965                 HANSAN     42          BIRBHUM   1942           1.430126
# 966                NALHATI     42          BIRBHUM   1942           1.138946
# 967                MURARAI     42          BIRBHUM   1942           1.086502
#
#      Shape_Area
# 674    0.046919
# 675    0.033107
# 676    0.034835
# 677    0.023555
# 678    0.046011
# ..          ...
# 963    0.034775
# 964    0.038697
# 965    0.026374
# 966    0.027210
# 967    0.026636
#
# [294 rows x 14 columns]

# %%
# goa for bye-election 
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('west_bengal_masterlist.xlsx', sheet_name=2)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)

# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.head()
print(df2)


def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df1.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'WEST BENGAL'].copy()  # Filter rows where ST_NAME is "GOA"
print(df1_state)




df2['FID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['FID'])
df2['OBJECTID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['OBJECTID'])
df2['ST_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_CODE'])
df2['ST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_NAME'])
df2['DT_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DT_CODE'])
df2['DIST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DIST_NAME'])
df2['AC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['AC_NO'])
df2['PC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NO'])
df2['PC_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NAME'])
df2['PC_ID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_ID'])
df2['STATUS'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['STATUS'])
df2['Shape_Leng'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Leng'])
df2['Shape_Area'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Area'])

# drop AC no
df2.drop(['AC no'], axis=1, inplace=True)
df2.drop(['State'], axis=1, inplace=True)

# print(df1)
df2.to_excel('WEST BENGAL bye.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    election  year  AC no        State          AC_NAME  Downloaded  Converted  \
# 0     VS_be  2016    263  West Bengal        Monteswar           0          0
# 1     VS_be  2017    216  West Bengal   kanthi dakshin           0          0
# 2     VS_be  2017    226  West Bengal           sabong           0          0
# 3     VS_be  2018    107  West Bengal          Noapara           0          0
# 4     VS_be  2018    155  West Bengal       Maheshtala           0          0
# 5     VS_be  2019     29  West Bengal         Islampur           1          1
# 6     VS_be  2019     23  West Bengal       Darjeeling           1          1
# 7     VS_be  2019     43  West Bengal         Habibpur           0          0
# 8     VS_be  2019     74  West Bengal            Nowda           1          1
# 9     VS_be  2019     68  West Bengal            Kandi           1          1
# 10    VS_be  2019     88  West Bengal      Krishnaganj           1          1
# 11    VS_be  2019    105  West Bengal         Bhatpara           1          1
# 12    VS_be  2019    176  West Bengal   Uluberia Purba           1          1
# 13    VS_be  2019     77  West Bengal         Karimpur           1          1
# 14    VS_be  2019     34  West Bengal        Kaliaganj           1          1
# 15    VS_be  2019    224  West Bengal  Kharagpur sadar           1          1
# 16    VS_be  2021     86  West Bengal         Santipur           0          0
# 17    VS_be  2021    109  West Bengal         Khardaha           0          0
# 18    VS_be  2021    127  West Bengal      Gosaba (SC)           0          0
# 19    VS_be  2021      7  West Bengal          Dinhata           0          0
# 20    VS_be  2021    159  West Bengal       Bhabanipur           0          0
# 21    VS_be  2022    161  West Bengal       Ballygunge           0          0
#
#     Cleaned               File Status   Error Comment  \
# 0         0            not downloaded             NaN
# 1         0            not downloaded             NaN
# 2         0            not downloaded             NaN
# 3         0            not downloaded             NaN
# 4         0            not downloaded             NaN
# 5         1              file cleaned  Data available
# 6         0  Downloaded and Converted      Image File
# 7         0            not downloaded             NaN
# 8         1              file cleaned  Data available
# 9         1              file cleaned  Data available
# 10        0  Downloaded and Converted      Image File
# 11        0  Downloaded and Converted      Image File
# 12        0  Downloaded and Converted      Image File
# 13        0  Downloaded and Converted      Image File
# 14        0  Downloaded and Converted      Image File
# 15        0  Downloaded and Converted      Image File
# 16        0            not downloaded             NaN
# 17        0            not downloaded             NaN
# 18        0            not downloaded             NaN
# 19        0            not downloaded             NaN
# 20        0            not downloaded             NaN
# 21        0            not downloaded             NaN
#
#                                                  Note
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   non numeric entries and some datas are not ava...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#      FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE   DIST_NAME  AC_NO  \
# 674  674         3       19  WEST BENGAL        3  KOCH BIHAR      1
# 675  675         1       19  WEST BENGAL        3  KOCH BIHAR      2
# 676  676         1       19  WEST BENGAL        3  KOCH BIHAR      3
# 677  677         1       19  WEST BENGAL        3  KOCH BIHAR      4
# 678  678         1       19  WEST BENGAL        3  KOCH BIHAR      5
# ..   ...       ...      ...          ...      ...         ...    ...
# 963  963        41       19  WEST BENGAL        8     BIRBHUM    290
# 964  964        42       19  WEST BENGAL        8     BIRBHUM    291
# 965  965        42       19  WEST BENGAL        8     BIRBHUM    292
# 966  966        42       19  WEST BENGAL        8     BIRBHUM    293
# 967  967        42       19  WEST BENGAL        8     BIRBHUM    294
#
#                    AC_NAME  PC_NO          PC_NAME  PC_ID STATUS  Shape_Leng  \
# 674         MEKLIGANJ (SC)      3  JALPAIGURI (SC)   1903           3.646516
# 675       MATHABHANGA (SC)      1  COOCHBEHAR (SC)   1901           1.329057
# 676  COOCHBEHAR UTTAR (SC)      1  COOCHBEHAR (SC)   1901           1.123028
# 677     COOCHBEHAR DAKSHIN      1  COOCHBEHAR (SC)   1901           0.861036
# 678        SITALKUCHI (SC)      1  COOCHBEHAR (SC)   1901           1.858278
# ..                     ...    ...              ...    ...    ...         ...
# 963             MAYURESWAR     41      BOLPUR (SC)   1941           1.062228
# 964              RAMPURHAT     42          BIRBHUM   1942           1.680656
# 965                 HANSAN     42          BIRBHUM   1942           1.430126
# 966                NALHATI     42          BIRBHUM   1942           1.138946
# 967                MURARAI     42          BIRBHUM   1942           1.086502
#
#      Shape_Area
# 674    0.046919
# 675    0.033107
# 676    0.034835
# 677    0.023555
# 678    0.046011
# ..          ...
# 963    0.034775
# 964    0.038697
# 965    0.026374
# 966    0.027210
# 967    0.026636
#
# [294 rows x 14 columns]
