# %%
 #install fuzzywuzzy
# !pip install fuzzywuzzy
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import fuzzywuzzy as fw
from fuzzywuzzy import process
import openpyxl as op
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('karnataka_masterlist.xlsx', sheet_name=0)
# df2 = pd.read_excel('goa_masterlist.xlsx')
# df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'Year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'KARNATAKA'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
# df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
df1_state['interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['interim'])
df1_state['Note'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Note'])


df1_state.to_excel('KARNATAKA vs 2018.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#        FID  OBJECTID  ST_CODE    ST_NAME  DT_CODE      DIST_NAME  AC_NO  \
# 2194  2194         7       29  KARNATAKA        5          BIDAR     52
# 2195  2195         7       29  KARNATAKA        5          BIDAR     51
# 2196  2196         7       29  KARNATAKA        5          BIDAR     50
# 2197  2197         7       29  KARNATAKA        5          BIDAR     47
# 2198  2198         7       29  KARNATAKA        5          BIDAR     49
# ...    ...       ...      ...        ...      ...            ...    ...
# 2414  2414        22       29  KARNATAKA       27  CHAMRAJNAGAR*    221
# 2415  2415        22       29  KARNATAKA       27  CHAMRAJNAGAR*    222
# 2416  2416        22       29  KARNATAKA       26         MYSORE    214
# 2417  2417        22       29  KARNATAKA       27  CHAMRAJNAGAR*    223
# 2418  2418        22       29  KARNATAKA       27  CHAMRAJNAGAR*    224
#
#              AC_NAME  PC_NO             PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2194      Aurad (SC)      7               BIDAR   2907           2.234798
# 2195          Bhalki      7               BIDAR   2907           2.059781
# 2196           Bidar      7               BIDAR   2907           1.149754
# 2197    Basavakalyan      7               BIDAR   2907           2.131104
# 2198     Bidar South      7               BIDAR   2907           1.758412
# ...              ...    ...                 ...    ...    ...         ...
# 2414           Hanur     22  CHAMARAJANAGAR(SC)   2922           2.328127
# 2415   Kollegal (SC)     22  CHAMARAJANAGAR(SC)   2922           1.531909
# 2416  Nanjangud (SC)     22  CHAMARAJANAGAR(SC)   2922           1.762062
# 2417  Chamarajanagar     22  CHAMARAJANAGAR(SC)   2922           1.838932
# 2418       Gundlupet     22  CHAMARAJANAGAR(SC)   2922           2.151281
#
#       Shape_Area
# 2194    0.106068
# 2195    0.095409
# 2196    0.029161
# 2197    0.085037
# 2198    0.071339
# ...          ...
# 2414    0.218994
# 2415    0.051580
# 2416    0.050160
# 2417    0.073507
# 2418    0.124455
#
# [225 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('karnataka_masterlist.xlsx', sheet_name=1)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)


df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'KARNATAKA'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
# df1_state['Interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Interim'])
df1_state['Note'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Note'])


df1_state.to_excel('KARNATAKA vs 2023.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#        FID  OBJECTID  ST_CODE    ST_NAME  DT_CODE      DIST_NAME  AC_NO  \
# 2194  2194         7       29  KARNATAKA        5          BIDAR     52
# 2195  2195         7       29  KARNATAKA        5          BIDAR     51
# 2196  2196         7       29  KARNATAKA        5          BIDAR     50
# 2197  2197         7       29  KARNATAKA        5          BIDAR     47
# 2198  2198         7       29  KARNATAKA        5          BIDAR     49
# ...    ...       ...      ...        ...      ...            ...    ...
# 2414  2414        22       29  KARNATAKA       27  CHAMRAJNAGAR*    221
# 2415  2415        22       29  KARNATAKA       27  CHAMRAJNAGAR*    222
# 2416  2416        22       29  KARNATAKA       26         MYSORE    214
# 2417  2417        22       29  KARNATAKA       27  CHAMRAJNAGAR*    223
# 2418  2418        22       29  KARNATAKA       27  CHAMRAJNAGAR*    224
#
#              AC_NAME  PC_NO             PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2194      Aurad (SC)      7               BIDAR   2907           2.234798
# 2195          Bhalki      7               BIDAR   2907           2.059781
# 2196           Bidar      7               BIDAR   2907           1.149754
# 2197    Basavakalyan      7               BIDAR   2907           2.131104
# 2198     Bidar South      7               BIDAR   2907           1.758412
# ...              ...    ...                 ...    ...    ...         ...
# 2414           Hanur     22  CHAMARAJANAGAR(SC)   2922           2.328127
# 2415   Kollegal (SC)     22  CHAMARAJANAGAR(SC)   2922           1.531909
# 2416  Nanjangud (SC)     22  CHAMARAJANAGAR(SC)   2922           1.762062
# 2417  Chamarajanagar     22  CHAMARAJANAGAR(SC)   2922           1.838932
# 2418       Gundlupet     22  CHAMARAJANAGAR(SC)   2922           2.151281
#
#       Shape_Area
# 2194    0.106068
# 2195    0.095409
# 2196    0.029161
# 2197    0.085037
# 2198    0.071339
# ...          ...
# 2414    0.218994
# 2415    0.051580
# 2416    0.050160
# 2417    0.073507
# 2418    0.124455
#
# [225 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# goa for bye-election 
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('karnataka_masterlist.xlsx', sheet_name=2)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)

# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.head()
print(df2)


def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df1.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'KARNATAKA'].copy()  # Filter rows where ST_NAME is "GOA"
print(df1_state)




df2['FID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['FID'])
df2['OBJECTID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['OBJECTID'])
df2['ST_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_CODE'])
df2['ST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_NAME'])
df2['DT_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DT_CODE'])
df2['DIST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DIST_NAME'])
df2['AC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['AC_NO'])
df2['PC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NO'])
df2['PC_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NAME'])
df2['PC_ID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_ID'])
df2['STATUS'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['STATUS'])
df2['Shape_Leng'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Leng'])
df2['Shape_Area'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Area'])

# drop AC no
df2.drop(['AC no'], axis=1, inplace=True)
df2.drop(['State'], axis=1, inplace=True)

# print(df1)
df2.to_excel('KARNATAKA bye.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    election  year  AC no      State               AC_NAME  Downloaded  \
# 0     VS_be  2019      3  Karnataka                Athani           1
# 1     VS_be  2021     47  Karnataka          Basavakalyan           0
# 2     VS_be  2019    141  Karnataka        Chikkaballapur           1
# 3     VS_be  2019     42  Karnataka             Chincholi           0
# 4     VS_be  2019      9  Karnataka                 Gokak           1
# 5     VS_be  2021     82  Karnataka                Hangal           1
# 6     VS_be  2019     86  Karnataka             Hirekerur           1
# 7     VS_be  2019    178  Karnataka              Hosakote           1
# 8     VS_be  2019    212  Karnataka              Hunasuru           1
# 9     VS_be  2018     21  Karnataka             Jamkhandi           0
# 10    VS_be  2019    151  Karnataka            K.R. Puram           0
# 11    VS_be  2019      4  Karnataka                Kagwad           1
# 12    VS_be  2019    192  Karnataka        Krishnarajpete           1
# 13    VS_be  2018      5  Karnataka               Kudachi           0
# 14    VS_be  2019     70  Karnataka               Kundgol           0
# 15    VS_be  2019    156  Karnataka    Mahalakshmi Layout           1
# 16    VS_be  2021     59  Karnataka                 Maski           0
# 17    VS_be  2020    154  Karnataka  Rajarajeshwari Nagar           1
# 18    VS_be  2018    183  Karnataka         Ramnagara LAC           0
# 19    VS_be  2019     87  Karnataka            Ranibennur           1
# 20    VS_be  2019    162  Karnataka          Shivajinagar           1
# 21    VS_be  2021     33  Karnataka                Sindgi           1
# 22    VS_be  2020    136  Karnataka                  Sira           1
# 23    VS_be  2019     90  Karnataka          Vijayanagara           1
# 24    VS_be  2019     81  Karnataka              Yellapur           1
# 25    VS_be  2019    153  Karnataka        Yeshvanthapura           1
#
#     Converted  cleaned               File Status   Error Comment  \
# 0           1        1              file cleaned  data available
# 1           0        0            not downloaded             NaN
# 2           1        0  Downloaded and Converted      Image File
# 3           0        0            not downloaded             NaN
# 4           1        1              file cleaned  data available
# 5           1        0  Downloaded and Converted      Image File
# 6           1        1              file cleaned  data available
# 7           1        0  Downloaded and Converted      Image File
# 8           1        0  Downloaded and Converted      Image File
# 9           0        0            not downloaded             NaN
# 10          0        0            not downloaded             NaN
# 11          1        1              file cleaned  data available
# 12          1        1              file cleaned  data available
# 13          0        0            not downloaded             NaN
# 14          0        0            not downloaded             NaN
# 15          1        1              file cleaned  data available
# 16          0        0            not downloaded             NaN
# 17          1        1              file cleaned  data available
# 18          0        0            not downloaded             NaN
# 19          1        0  Downloaded and Converted      Image File
# 20          1        0  Downloaded and Converted      Image File
# 21          1        0  Downloaded and Converted      Image File
# 22          1        1              file cleaned  data available
# 23          1        0  Downloaded and Converted      Image File
# 24          1        1              file cleaned  data available
# 25          1        1              file cleaned  data available
#
#                           Note
# 0   polling booth name missing
# 1                          NaN
# 2         pictures and jumbled
# 3                          NaN
# 4   polling booth name missing
# 5                          NaN
# 6   polling booth name missing
# 7         pictures and jumbled
# 8                image in file
# 9                          NaN
# 10                         NaN
# 11  polling booth name missing
# 12  polling booth name missing
# 13                         NaN
# 14                         NaN
# 15  polling booth name missing
# 16                         NaN
# 17  polling booth name missing
# 18                         NaN
# 19        pictures and jumbled
# 20                    pictures
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24  polling booth name missing
# 25  polling booth name missing
#        FID  OBJECTID  ST_CODE    ST_NAME  DT_CODE      DIST_NAME  AC_NO  \
# 2194  2194         7       29  KARNATAKA        5          BIDAR     52
# 2195  2195         7       29  KARNATAKA        5          BIDAR     51
# 2196  2196         7       29  KARNATAKA        5          BIDAR     50
# 2197  2197         7       29  KARNATAKA        5          BIDAR     47
# 2198  2198         7       29  KARNATAKA        5          BIDAR     49
# ...    ...       ...      ...        ...      ...            ...    ...
# 2414  2414        22       29  KARNATAKA       27  CHAMRAJNAGAR*    221
# 2415  2415        22       29  KARNATAKA       27  CHAMRAJNAGAR*    222
# 2416  2416        22       29  KARNATAKA       26         MYSORE    214
# 2417  2417        22       29  KARNATAKA       27  CHAMRAJNAGAR*    223
# 2418  2418        22       29  KARNATAKA       27  CHAMRAJNAGAR*    224
#
#              AC_NAME  PC_NO             PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2194      Aurad (SC)      7               BIDAR   2907           2.234798
# 2195          Bhalki      7               BIDAR   2907           2.059781
# 2196           Bidar      7               BIDAR   2907           1.149754
# 2197    Basavakalyan      7               BIDAR   2907           2.131104
# 2198     Bidar South      7               BIDAR   2907           1.758412
# ...              ...    ...                 ...    ...    ...         ...
# 2414           Hanur     22  CHAMARAJANAGAR(SC)   2922           2.328127
# 2415   Kollegal (SC)     22  CHAMARAJANAGAR(SC)   2922           1.531909
# 2416  Nanjangud (SC)     22  CHAMARAJANAGAR(SC)   2922           1.762062
# 2417  Chamarajanagar     22  CHAMARAJANAGAR(SC)   2922           1.838932
# 2418       Gundlupet     22  CHAMARAJANAGAR(SC)   2922           2.151281
#
#       Shape_Area
# 2194    0.106068
# 2195    0.095409
# 2196    0.029161
# 2197    0.085037
# 2198    0.071339
# ...          ...
# 2414    0.218994
# 2415    0.051580
# 2416    0.050160
# 2417    0.073507
# 2418    0.124455
#
# [225 rows x 14 columns]
