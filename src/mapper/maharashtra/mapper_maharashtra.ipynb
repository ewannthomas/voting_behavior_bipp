# %%
 #install fuzzywuzzy
# !pip install fuzzywuzzy
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fuzzywuzzy in /home/tarun/.local/lib/python3.10/site-packages (0.18.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /home/tarun/.local/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/tarun/.local/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import fuzzywuzzy as fw
from fuzzywuzzy import process
import openpyxl as op
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('maharashtra_masterlist.xlsx', sheet_name=0)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status ': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'MAHARASHTRA'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
df1_state['interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['interim'])


df1_state.to_excel('Maharashtra vs 2014.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#        FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE    DIST_NAME  AC_NO  \
# 2645  2645         1       27  MAHARASHTRA        1  NANDURBAR *      1
# 2646  2646         1       27  MAHARASHTRA        1  NANDURBAR *      2
# 2647  2647         7       27  MAHARASHTRA        7     AMRAVATI     41
# 2648  2648         1       27  MAHARASHTRA        1  NANDURBAR *      3
# 2649  2649         1       27  MAHARASHTRA        2        DHULE      9
# ...    ...       ...      ...          ...      ...          ...    ...
# 2942  2942        47       27  MAHARASHTRA       34     KOLHAPUR    272
# 2943  2943        47       27  MAHARASHTRA       34     KOLHAPUR    273
# 2944  2944        46       27  MAHARASHTRA       33   SINDHUDURG    269
# 2945  2945        47       27  MAHARASHTRA       34     KOLHAPUR    271
# 2946  2946        46       27  MAHARASHTRA       33   SINDHUDURG    270
#
#              AC_NAME  PC_NO               PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2645  Akkalkuwa (ST)      1        NANDURBAR (ST)   2701           2.894388
# 2646    Shahada (ST)      1        NANDURBAR (ST)   2701           2.618610
# 2647    Melghat (ST)      7         AMRAVATI (SC)   2707           3.711428
# 2648  Nandurbar (ST)      1        NANDURBAR (ST)   2701           2.580283
# 2649    Shirpur (ST)      1        NANDURBAR (ST)   2701           1.728193
# ...              ...    ...                   ...    ...    ...         ...
# 2942     Radhanagari     47              KOLHAPUR   2747           3.230545
# 2943           Kagal     47              KOLHAPUR   2747           2.411815
# 2944           Kudal     46  RATNAGIRI ?SINDHUDUR   2746           2.407060
# 2945        Chandgad     47              KOLHAPUR   2747           2.750061
# 2946      Sawantwadi     46  RATNAGIRI ?SINDHUDUR   2746           3.013116
#
#       Shape_Area
# 2645    0.194806
# 2646    0.094384
# 2647    0.375752
# 2648    0.109140
# 2649    0.131644
# ...          ...
# 2942    0.151146
# 2943    0.064359
# 2944    0.122333
# 2945    0.127986
# 2946    0.138856
#
# [302 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('maharashtra_masterlist.xlsx', sheet_name=1)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status ': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'MAHARASHTRA'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
# df1_state['interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['interim'])
# df1_state['Note'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Note'])


df1_state.to_excel('MAHARASHTRA vs 2019.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#        FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE    DIST_NAME  AC_NO  \
# 2645  2645         1       27  MAHARASHTRA        1  NANDURBAR *      1
# 2646  2646         1       27  MAHARASHTRA        1  NANDURBAR *      2
# 2647  2647         7       27  MAHARASHTRA        7     AMRAVATI     41
# 2648  2648         1       27  MAHARASHTRA        1  NANDURBAR *      3
# 2649  2649         1       27  MAHARASHTRA        2        DHULE      9
# ...    ...       ...      ...          ...      ...          ...    ...
# 2942  2942        47       27  MAHARASHTRA       34     KOLHAPUR    272
# 2943  2943        47       27  MAHARASHTRA       34     KOLHAPUR    273
# 2944  2944        46       27  MAHARASHTRA       33   SINDHUDURG    269
# 2945  2945        47       27  MAHARASHTRA       34     KOLHAPUR    271
# 2946  2946        46       27  MAHARASHTRA       33   SINDHUDURG    270
#
#              AC_NAME  PC_NO               PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2645  Akkalkuwa (ST)      1        NANDURBAR (ST)   2701           2.894388
# 2646    Shahada (ST)      1        NANDURBAR (ST)   2701           2.618610
# 2647    Melghat (ST)      7         AMRAVATI (SC)   2707           3.711428
# 2648  Nandurbar (ST)      1        NANDURBAR (ST)   2701           2.580283
# 2649    Shirpur (ST)      1        NANDURBAR (ST)   2701           1.728193
# ...              ...    ...                   ...    ...    ...         ...
# 2942     Radhanagari     47              KOLHAPUR   2747           3.230545
# 2943           Kagal     47              KOLHAPUR   2747           2.411815
# 2944           Kudal     46  RATNAGIRI ?SINDHUDUR   2746           2.407060
# 2945        Chandgad     47              KOLHAPUR   2747           2.750061
# 2946      Sawantwadi     46  RATNAGIRI ?SINDHUDUR   2746           3.013116
#
#       Shape_Area
# 2645    0.194806
# 2646    0.094384
# 2647    0.375752
# 2648    0.109140
# 2649    0.131644
# ...          ...
# 2942    0.151146
# 2943    0.064359
# 2944    0.122333
# 2945    0.127986
# 2946    0.138856
#
# [302 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# goa for bye-election 
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('maharashtra_masterlist.xlsx', sheet_name=2)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)

# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.head()
print(df2)


def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df1.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'MAHARASHTRA'].copy()  # Filter rows where ST_NAME is "GOA"
print(df1_state)




df2['FID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['FID'])
df2['OBJECTID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['OBJECTID'])
df2['ST_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_CODE'])
df2['ST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_NAME'])
df2['DT_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DT_CODE'])
df2['DIST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DIST_NAME'])
df2['AC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['AC_NO'])
df2['PC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NO'])
df2['PC_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NAME'])
df2['PC_ID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_ID'])
df2['STATUS'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['STATUS'])
df2['Shape_Leng'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Leng'])
df2['Shape_Area'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Area'])

# drop AC no
df2.drop(['AC no'], axis=1, inplace=True)
df2.drop(['State'], axis=1, inplace=True)

# print(df1)
df2.to_excel('Maharashtra bye.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#         election  year  AC no        State                   AC_NAME  \
# 0   bye_election  2014     33  Maharashtra                     risod
# 1   bye_election  2015     91  Maharashtra                    mukhed
# 2   bye_election  2015    107  Maharashtra                     dhuri
# 3   bye_election  2015    315  Maharashtra                   farenda
# 4   bye_election  2015    287  Maharashtra  Tasgaon Kavathe Mahankal
# 5   bye_election  2015    176  Maharashtra               vandre_east
# 6   bye_election  2015    231  Maharashtra                 charkhari
# 7   bye_election  2018    285  Maharashtra            Palus Kadegaon
# 8   bye_election  2021     90  Maharashtra               Deglur (SC)
# 9   bye_election  2021    252  Maharashtra                Pandharpur
# 10  bye_election  2022    166  Maharashtra              Andheri East
# 11  bye_election  2022    276  Maharashtra            Kolhapur North
# 12  bye_election  2023    205  Maharashtra                 Chinchwad
# 13  bye_election  2023    215  Maharashtra                Kasba_peth
#
#     Downloaded  Converted  Cleaned               File Status   Error Comment  \
# 0            0          0        0            not downloaded             NaN
# 1            0          0        0            not downloaded             NaN
# 2            0          0        0            not downloaded             NaN
# 3            0          0        0            not downloaded             NaN
# 4            0          0        0            not downloaded             NaN
# 5            0          0        0            not downloaded             NaN
# 6            0          0        0            not downloaded             NaN
# 7            0          0        0            not downloaded             NaN
# 8            1          1        0  Downloaded and Converted      image file
# 9            1          1        0  Downloaded and Converted      image file
# 10           1          1        1              file cleaned  data available
# 11           1          1        1              file cleaned  data available
# 12           1          1        1              file cleaned  data available
# 13           1          1        1              file cleaned  data available
#
#                     Unnamed: 10
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8       alpha numeric enteries
# 9       alpha numeric enteries
# 10  polling station name absent
# 11  polling station name absent
# 12  polling station name absent
# 13  polling station name absent
#        FID  OBJECTID  ST_CODE      ST_NAME  DT_CODE    DIST_NAME  AC_NO  \
# 2645  2645         1       27  MAHARASHTRA        1  NANDURBAR *      1
# 2646  2646         1       27  MAHARASHTRA        1  NANDURBAR *      2
# 2647  2647         7       27  MAHARASHTRA        7     AMRAVATI     41
# 2648  2648         1       27  MAHARASHTRA        1  NANDURBAR *      3
# 2649  2649         1       27  MAHARASHTRA        2        DHULE      9
# ...    ...       ...      ...          ...      ...          ...    ...
# 2942  2942        47       27  MAHARASHTRA       34     KOLHAPUR    272
# 2943  2943        47       27  MAHARASHTRA       34     KOLHAPUR    273
# 2944  2944        46       27  MAHARASHTRA       33   SINDHUDURG    269
# 2945  2945        47       27  MAHARASHTRA       34     KOLHAPUR    271
# 2946  2946        46       27  MAHARASHTRA       33   SINDHUDURG    270
#
#              AC_NAME  PC_NO               PC_NAME  PC_ID STATUS  Shape_Leng  \
# 2645  Akkalkuwa (ST)      1        NANDURBAR (ST)   2701           2.894388
# 2646    Shahada (ST)      1        NANDURBAR (ST)   2701           2.618610
# 2647    Melghat (ST)      7         AMRAVATI (SC)   2707           3.711428
# 2648  Nandurbar (ST)      1        NANDURBAR (ST)   2701           2.580283
# 2649    Shirpur (ST)      1        NANDURBAR (ST)   2701           1.728193
# ...              ...    ...                   ...    ...    ...         ...
# 2942     Radhanagari     47              KOLHAPUR   2747           3.230545
# 2943           Kagal     47              KOLHAPUR   2747           2.411815
# 2944           Kudal     46  RATNAGIRI ?SINDHUDUR   2746           2.407060
# 2945        Chandgad     47              KOLHAPUR   2747           2.750061
# 2946      Sawantwadi     46  RATNAGIRI ?SINDHUDUR   2746           3.013116
#
#       Shape_Area
# 2645    0.194806
# 2646    0.094384
# 2647    0.375752
# 2648    0.109140
# 2649    0.131644
# ...          ...
# 2942    0.151146
# 2943    0.064359
# 2944    0.122333
# 2945    0.127986
# 2946    0.138856
#
# [302 rows x 14 columns]
