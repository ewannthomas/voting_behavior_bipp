# %%
 #install fuzzywuzzy
# !pip install fuzzywuzzy
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np
from pathlib import Path

import fuzzywuzzy as fw
from fuzzywuzzy import process
import openpyxl as op
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('gujarat_masterlist.xlsx', sheet_name=0)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'GUJARAT'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
df1_state['interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['interim'])


df1_state.to_excel('gujarat vs 2017.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
#        FID  OBJECTID  ST_CODE  ST_NAME  DT_CODE     DIST_NAME  AC_NO  \
# 1769  1769         0       24  GUJARAT        1       KACHCHH      0
# 1770  1770         2       24  GUJARAT        2  BANAS KANTHA      8
# 1771  1771         2       24  GUJARAT        2  BANAS KANTHA      7
# 1772  1772         2       24  GUJARAT        2  BANAS KANTHA      9
# 1773  1773         2       24  GUJARAT        2  BANAS KANTHA     10
# ...    ...       ...      ...      ...      ...           ...    ...
# 1936  1936        26       24  GUJARAT       25        VALSAD    179
# 1937  1937        26       24  GUJARAT       25        VALSAD    178
# 1938  1938        26       24  GUJARAT       25        VALSAD    180
# 1939  1939        26       24  GUJARAT       25        VALSAD    181
# 1940  1940        26       24  GUJARAT       24    NAVSARI  *    182
#
#            AC_NAME  PC_NO      PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area
# 1769                    0                2400          25.143971    1.906816
# 1770        Tharad      2  BANASKANTHA   2402           1.887743    0.122525
# 1771           Vav      2  BANASKANTHA   2402           4.445085    0.191950
# 1772       Dhanera      2  BANASKANTHA   2402           2.752790    0.113032
# 1773    Danta (ST)      2  BANASKANTHA   2402           2.224722    0.141855
# ...            ...    ...          ...    ...    ...         ...         ...
# 1936        Valsad     26  VALSAD (ST)   2426           0.850107    0.022375
# 1937     Dharampur     26  VALSAD (ST)   2426           1.736108    0.084710
# 1938         Pardi     26  VALSAD (ST)   2426           1.028972    0.020517
# 1939  Kaprada (ST)     26  VALSAD (ST)   2426           2.393571    0.095038
# 1940     Umbergaon     26  VALSAD (ST)   2426           1.125306    0.032672
#
# [172 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# odisha
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('gujarat_masterlist.xlsx', sheet_name=1)
# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.rename(columns={'Cleaned': 'cleaned'}, inplace=True)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)
df2.rename(columns={'File Status': 'File Status'}, inplace=True)
df2.rename(columns={'Error Comment': 'Error Comment'}, inplace=True)
df2.rename(columns={'year': 'year'}, inplace=True)

df2.head()



def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df2.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'GUJARAT'].copy()  # Filter rows where ST_NAME is "ODISHA"
print(df1_state)
df1_state['Downloaded'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Downloaded'])
df1_state['year'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['year'])
df1_state['Converted'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Converted'])
df1_state['cleaned'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['cleaned'])
df1_state['File Status'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['File Status'])
df1_state['Error Comment'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['Error Comment'])
df1_state['election'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['election'])
df1_state['interim'] = df1_state['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df2['AC_NAME'])]['interim'])


df1_state.to_excel('GUJARAT vs 2022.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
#        FID  OBJECTID  ST_CODE  ST_NAME  DT_CODE     DIST_NAME  AC_NO  \
# 1769  1769         0       24  GUJARAT        1       KACHCHH      0
# 1770  1770         2       24  GUJARAT        2  BANAS KANTHA      8
# 1771  1771         2       24  GUJARAT        2  BANAS KANTHA      7
# 1772  1772         2       24  GUJARAT        2  BANAS KANTHA      9
# 1773  1773         2       24  GUJARAT        2  BANAS KANTHA     10
# ...    ...       ...      ...      ...      ...           ...    ...
# 1936  1936        26       24  GUJARAT       25        VALSAD    179
# 1937  1937        26       24  GUJARAT       25        VALSAD    178
# 1938  1938        26       24  GUJARAT       25        VALSAD    180
# 1939  1939        26       24  GUJARAT       25        VALSAD    181
# 1940  1940        26       24  GUJARAT       24    NAVSARI  *    182
#
#            AC_NAME  PC_NO      PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area
# 1769                    0                2400          25.143971    1.906816
# 1770        Tharad      2  BANASKANTHA   2402           1.887743    0.122525
# 1771           Vav      2  BANASKANTHA   2402           4.445085    0.191950
# 1772       Dhanera      2  BANASKANTHA   2402           2.752790    0.113032
# 1773    Danta (ST)      2  BANASKANTHA   2402           2.224722    0.141855
# ...            ...    ...          ...    ...    ...         ...         ...
# 1936        Valsad     26  VALSAD (ST)   2426           0.850107    0.022375
# 1937     Dharampur     26  VALSAD (ST)   2426           1.736108    0.084710
# 1938         Pardi     26  VALSAD (ST)   2426           1.028972    0.020517
# 1939  Kaprada (ST)     26  VALSAD (ST)   2426           2.393571    0.095038
# 1940     Umbergaon     26  VALSAD (ST)   2426           1.125306    0.032672
#
# [172 rows x 14 columns]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ' ']

# %%
# goa for bye-election 
df1 = pd.read_excel('India_AC_shapefile.xlsx')
df1.head()
# read sheet 2 of goa masterlist
df2 = pd.read_excel('gujarat_masterlist.xlsx', sheet_name=2)
df2.rename(columns={'assembly constituency': 'AC_NAME'}, inplace=True)

# df2 = pd.read_excel('goa_masterlist.xlsx')
df2.head()
print(df2)


def find_fuzzy_match(name, choices):
    if not name:
        return None
    result = process.extractOne(name, choices)
    if result:
        return result[0]
    else:
        return None

# Create a mapping dictionary for rows in df2
ac_name_mapping = {row['AC_NAME']: row for idx, row in df1.iterrows()}

# Filter df1 for rows with ST_NAME "GOA" and map columns from df2 based on fuzzy matching
df1_state = df1[df1['ST_NAME'] == 'GUJARAT'].copy()  # Filter rows where ST_NAME is "GOA"
print(df1_state)




df2['FID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['FID'])
df2['OBJECTID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['OBJECTID'])
df2['ST_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_CODE'])
df2['ST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['ST_NAME'])
df2['DT_CODE'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DT_CODE'])
df2['DIST_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['DIST_NAME'])
df2['AC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['AC_NO'])
df2['PC_NO'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NO'])
df2['PC_NAME'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_NAME'])
df2['PC_ID'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['PC_ID'])
df2['STATUS'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['STATUS'])
df2['Shape_Leng'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Leng'])
df2['Shape_Area'] = df2['AC_NAME'].apply(lambda x: ac_name_mapping[find_fuzzy_match(x, df1_state['AC_NAME'])]['Shape_Area'])

# drop AC no
df2.drop(['AC no'], axis=1, inplace=True)
df2.drop(['State'], axis=1, inplace=True)

# print(df1)
df2.to_excel('GUJARAT bye.xlsx', index=False)
# Out:
# /home/tarun/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    election  year  AC no    State         AC_NAME  Downloaded  Converted  \
# 0     VS_be  2018     72  Gujarat          Jasdan           1          1
# 1     VS_be  2019     64  Gujarat    Dharangadhra           1          0
# 2     VS_be  2019     77  Gujarat  Jamnagar Rural           1          1
# 3     VS_be  2019     85  Gujarat       Manavadar           1          1
# 4     VS_be  2019     21  Gujarat           Unjha           1          1
# 5     VS_be  2019     16  Gujarat       Radhanpur           1          1
# 6     VS_be  2019     32  Gujarat           Bayad           1          1
# 7     VS_be  2019      8  Gujarat          Tharad           1          1
# 8     VS_be  2019     20  Gujarat         Kheralu           1          1
# 9     VS_be  2019     50  Gujarat       Amraiwadi           1          1
# 10    VS_be  2019    122  Gujarat        Lunawada           1          1
# 11    VS_be  2020      1  Gujarat          Abdasa           1          1
# 12    VS_be  2020     61  Gujarat           Limdi           1          1
# 13    VS_be  2020     65  Gujarat           Morbi           1          1
# 14    VS_be  2020     94  Gujarat           Dhari           1          1
# 15    VS_be  2020    106  Gujarat         Gadhada           1          1
# 16    VS_be  2020    147  Gujarat          Karjan           1          1
# 17    VS_be  2020    173  Gujarat            Dang           1          1
# 18    VS_be  2020    181  Gujarat        Kaparada           1          1
# 19    VS_be  2021    125  Gujarat     Morva Hadaf           1          1
#
#     Cleaned interim   File Status  \
# 0         1     yes  file cleaned
# 1         0      no    image file
# 2         1     yes  file cleaned
# 3         1     yes  file cleaned
# 4         1     yes  file cleaned
# 5         1     yes  file cleaned
# 6         1     yes  file cleaned
# 7         1     yes  file cleaned
# 8         1     yes  file cleaned
# 9         1     yes  file cleaned
# 10        1     yes  file cleaned
# 11        1     yes  file cleaned
# 12        1     yes  file cleaned
# 13        1     yes  file cleaned
# 14        1     yes  file cleaned
# 15        1     yes  file cleaned
# 16        1     yes  file cleaned
# 17        1     yes  file cleaned
# 18        1     yes  file cleaned
# 19        1     yes  file cleaned
#
#                                         Error Comment
# 0                   polling station names are missing
# 1                                                 NaN
# 2                                                 NaN
# 3                   polling station names are missing
# 4                                                 NaN
# 5   polling station names are missing, language er...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                  polling station names are missing
# 12                                                NaN
# 13                  polling station names are missing
# 14                  polling station names are missing
# 15                  polling station names are missing
# 16                  polling station names are missing
# 17                  polling station names are missing
# 18                  polling station names are missing
# 19                                                NaN
#        FID  OBJECTID  ST_CODE  ST_NAME  DT_CODE     DIST_NAME  AC_NO  \
# 1769  1769         0       24  GUJARAT        1       KACHCHH      0
# 1770  1770         2       24  GUJARAT        2  BANAS KANTHA      8
# 1771  1771         2       24  GUJARAT        2  BANAS KANTHA      7
# 1772  1772         2       24  GUJARAT        2  BANAS KANTHA      9
# 1773  1773         2       24  GUJARAT        2  BANAS KANTHA     10
# ...    ...       ...      ...      ...      ...           ...    ...
# 1936  1936        26       24  GUJARAT       25        VALSAD    179
# 1937  1937        26       24  GUJARAT       25        VALSAD    178
# 1938  1938        26       24  GUJARAT       25        VALSAD    180
# 1939  1939        26       24  GUJARAT       25        VALSAD    181
# 1940  1940        26       24  GUJARAT       24    NAVSARI  *    182
#
#            AC_NAME  PC_NO      PC_NAME  PC_ID STATUS  Shape_Leng  Shape_Area
# 1769                    0                2400          25.143971    1.906816
# 1770        Tharad      2  BANASKANTHA   2402           1.887743    0.122525
# 1771           Vav      2  BANASKANTHA   2402           4.445085    0.191950
# 1772       Dhanera      2  BANASKANTHA   2402           2.752790    0.113032
# 1773    Danta (ST)      2  BANASKANTHA   2402           2.224722    0.141855
# ...            ...    ...          ...    ...    ...         ...         ...
# 1936        Valsad     26  VALSAD (ST)   2426           0.850107    0.022375
# 1937     Dharampur     26  VALSAD (ST)   2426           1.736108    0.084710
# 1938         Pardi     26  VALSAD (ST)   2426           1.028972    0.020517
# 1939  Kaprada (ST)     26  VALSAD (ST)   2426           2.393571    0.095038
# 1940     Umbergaon     26  VALSAD (ST)   2426           1.125306    0.032672
#
# [172 rows x 14 columns]
